# %% [markdown]
# В этом домашнем задании вам предстоит с помощью Pandas ответить на несколько вопросов об этом [датасете](https://archive.ics.uci.edu/ml/datasets/Adult). Все ответы вам предстоит отправить в этой [форме](https://forms.gle/qfVth9BygS4AVJZ47)
#
# Чтобы начать надо сохранить этот ноутбук себе на диск (File - Save a copy in Drive) или скачать (File - Download), если вы делаете у себя локально.
#
# Скачать нужный датасет можно [тут](https://disk.yandex.ru/d/6WlIXR-y_PObLg)
#
# Эта домашняя работа легкая и покрывает лишь некоторую базу, очень советую пройтись по доп.материалам и посмотреть на различные крутые штуки, которые может делать Pandas, Matplotlib или Seaborn. Особенно если вы хотите заниматься анализом данных намного серьезнее.
#
# Мягкий дедлайн: 31 октября 23:59 \
# Жесткий дедлайн: 7 ноября 23:59

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (18, 10)

# %% [markdown]
# **Задание 0: Прочитайте скачанный датасет и выведите его**

# %%
df = pd.read_csv('adult_data.csv')
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# **Задание 1: Найдите количество мужчин и количество женщин в датасете**

# %%
df.sex.value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %% [markdown]
# **Задание 2: Найдите средний возраст мужчин**

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %%
average_age = df[(df.sex == 'Male')]

average_age['age']
# Out:
# 0        39
# 1        50
# 2        38
# 3        53
# 7        52
#          ..
# 32553    32
# 32554    53
# 32555    22
# 32557    40
# 32559    22
# Name: age, Length: 21790, dtype: int64

# %%
average_age.age.mean
# Out:
# <bound method Series.mean of 0        39
# 1        50
# 2        38
# 3        53
# 7        52
#          ..
# 32553    32
# 32554    53
# 32555    22
# 32557    40
# 32559    22
# Name: age, Length: 21790, dtype: int64>

# %% [markdown]
# **Задание 3: Найдите процент людей, которые являются гражданами Тайваня (Taiwan)**

# %%
df['native-country'] == 'Taiwan'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: native-country, Length: 32561, dtype: bool

# %% [markdown]
# **Задание 4: Найдите среднее значение возраста для людей, которые зарабатывают >50K**

# %%
zarplata=df[df['salary']=='>50K']
print (zarplata.age.mean())
# Out:
# 44.24984058155847

# %% [markdown]
# **Задание 5: Найдите стандартное отклонение возраста для людей, которые зарабатывают >50K**

# %%
zarplata=df[df['salary']=='>50K']
print (zarplata.age.std())
# Out:
# 10.51902771985177

# %% [markdown]
# **Задание 6: Проверьте, правда ли что все люди, которые зарабытвают >50K, имеют образование Bachelors+**

# %%
bach=['Bachelors', 'Masters', 'Prof-school', 'Doctorate']
obr=zarplata[zarplata['education'].isin(bach)]
if len(zarplata)==len(obr):
  print('это правда')
else:
  print('это не правда')
# Out:
# это не правда

# %% [markdown]
# **Задание 7: Сколько человек, работающих 40 часов и являющихся гражданами США (United-States), зарабатывают <=50K**

# %%
df_7=df[(df['hours-per-week']== 40) & (df['native-country']=='United-States') & (df.salary == '<=50K')]
print(len(df_7))
# Out:
# 10493

# %% [markdown]
# **Задание 8: Теперь чуть сложнее. Давайте найдем максимальное количество часов в неделю (hours-per-week), а потом посмотрим, сколько человек работают столько времени в неделю и зарабатывают <=50K**

# %%
hoursmax=df['hours-per-week'].max()
df_8=df[(df.salary == '<=50K') & (df['hours-per-week']==hoursmax)]
print(len(df_8))
# Out:
# 60

# %% [markdown]
# **Задание 9: В этом задании вам предстоит построить ваш первый график. Ответьте на вопрос: людей с каким образованием больше всего представленно в датасете? \
# P.S Использовать можно matplotlib, seaborn, plotly**

# %%
plt.figure(figsize=(12, 6))
education_counts = df['education'].value_counts()

# Создание bar plot
sns.barplot(x=education_counts.values, y=education_counts.index, palette='viridis')
plt.title('Распределение людей по уровню образования')
plt.xlabel('Количество людей')
plt.ylabel('Уровень образования')
plt.tight_layout()
plt.show()

# Вывод точных чисел
print("Количество людей по уровням образования:")
print(education_counts)
# Out:
# /tmp/ipython-input-3783461415.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=education_counts.values, y=education_counts.index, palette='viridis')
# Количество людей по уровням образования:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64

# %% [markdown]
# **Задание 10: А теперь давайте посмотрим на распределение возрастов. Сколько возрастных отрезков имеют больше 1600 значений? (Одним "отрезков" является один столбец при стандартных настройках seaborn/matplotlib)
# P.S. Необязательное задание, хотя лучше сделать, если собираетесь сдавать до мягкого, я хоты бы посмотрю**

# %%
plt.figure(figsize=(12, 6))
n, bins, patches = plt.hist(df['age'], bins=30, edgecolor='black', alpha=0.7)
plt.title('Распределение возрастов в датасете')
plt.xlabel('Возраст')
plt.ylabel('Количество людей')
plt.grid(True, alpha=0.3)

# Подсчет столбцов с более чем 1600 значений
count_above_1600 = np.sum(n > 1600)
print(f"Количество возрастных отрезков с более чем 1600 значений: {count_above_1600}")

# Визуальное выделение столбцов с >1600 значений
for i, patch in enumerate(patches):
    if n[i] > 1600:
        patch.set_facecolor('red')
    else:
        patch.set_facecolor('skyblue')

# Добавление горизонтальной линии на уровне 1600
plt.axhline(y=1600, color='red', linestyle='--', alpha=0.7, label='1600 человек')
plt.legend()

plt.tight_layout()
plt.show()

# Дополнительная информация
print(f"\nОбщее количество биннов: {len(n)}")
print(f"Максимальное количество в одном бинне: {n.max():.0f}")
print(f"Минимальное количество в одном бинне: {n.min():.0f}")
print(f"Среднее количество в бинне: {n.mean():.1f}")

# Покажем какие именно бинны имеют >1600 значений
print("\nБинны с более чем 1600 значений:")
for i, count in enumerate(n):
    if count > 1600:
        print(f"Бинн {i+1}: возраст {bins[i]:.1f}-{bins[i+1]:.1f}, количество: {count:.0f}")
# Out:
# Количество возрастных отрезков с более чем 1600 значений: 11
# Общее количество биннов: 30
# Максимальное количество в одном бинне: 2589
# Минимальное количество в одном бинне: 2
# Среднее количество в бинне: 1085.4
#
# Бинны с более чем 1600 значений:
# Бинн 1: возраст 17.0-19.4, количество: 1657
# Бинн 3: возраст 21.9-24.3, количество: 2440
# Бинн 4: возраст 24.3-26.7, количество: 1626
# Бинн 5: возраст 26.7-29.2, количество: 2515
# Бинн 6: возраст 29.2-31.6, количество: 1749
# Бинн 7: возраст 31.6-34.0, количество: 2589
# Бинн 8: возраст 34.0-36.5, количество: 1774
# Бинн 9: возраст 36.5-38.9, количество: 1685
# Бинн 10: возраст 38.9-41.3, количество: 2418
# Бинн 12: возраст 43.8-46.2, количество: 2195
# Бинн 14: возраст 48.6-51.1, количество: 1774
